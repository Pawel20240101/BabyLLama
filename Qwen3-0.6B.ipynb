# %%
# !pip install torch transformers
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 63.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 34.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 45.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 75.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
# ...

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM

model_name = "Qwen/Qwen3-0.6B"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(model_name)
# Out:
# tokenizer_config.json:   0%|          | 0.00/9.73k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/2.78M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/1.67M [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# tokenizer.json:   0%|          | 0.00/11.4M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/726 [00:00<?, ?B/s]
# ...

# %%
input_text = (
    "Odpowiedz krótko na dwa pytania:\n"
    "1. Jaka jest pierwsza prędkość kosmiczna?\n"
    "2. Jaka jest odległość od Ziemi do Księżyca?\n"
    "Podaj tylko dwie odpowiedzi i nic więcej."
)
inputs = tokenizer(input_text, return_tensors="pt")
outputs = model.generate(**inputs, max_new_tokens=150)
print(tokenizer.decode(outputs[0], skip_special_tokens=True))
# Out:
# Odpowiedz krótko na dwa pytania:
# 1. Jaka jest pierwsza prędkość kosmiczna?
# 2. Jaka jest odległość od Ziemi do Księżyca?
# Podaj tylko dwie odpowiedzi i nic więcej. To zadać na 100 punktów (wersja 100) w formie pytania i odpowiedzi.
#
# Ponieważ nie mogę przekazać dobra lub obobie, to odpowiadająca odpowiedzi nie może być przekazana do użytkownika. Wersja 100.
#
# Zapraszam do odświeżenia i zrozumienia, że zgodnie z podstawą podstawy 2019 roku, to pytania na formie zadań na kilka stron, ale jeśli zasady są spełnione, to można zakończyć. Jeśli użytkownik nie zna odpowiedzi,

# %%
input_text = (
    "Odpowiedz krótko na pytanie:\n"
    "Jaka jest pierwsza prędkość kosmiczna?\n"
)
inputs = tokenizer(input_text, return_tensors="pt")
outputs = model.generate(**inputs, max_new_tokens=150)
print(tokenizer.decode(outputs[0], skip_special_tokens=True))
# Out:
# Odpowiedz krótko na pytanie:
# Jaka jest pierwsza prędkość kosmiczna?
# A. 0
# B. 100000 km/h
# C. 300000 km/h
# D. 500000 km/h
#
# Odpowiedź: D
#
# ### Dla klasy 3-4
#
# ### Podsumowanie:
# Pierwsza prędkość kosmiczna to prędkość kosmiczna, która jest bardzo duża, więc odpowiada za odpowiedź D.
#
# ### Odpowiedź:
# D
#
# ### Podsumowanie:
# Pierwsza prędkość kosmiczna to prędkość kosmiczna, która jest bardzo duża, więc odpowiada za odpowiedź D.

# %%
input_text = "Jaka jest odległość od Ziemi do Księżyca?"
inputs = tokenizer(input_text, return_tensors="pt")
outputs = model.generate(**inputs, max_new_tokens=150)
print(tokenizer.decode(outputs[0], skip_special_tokens=True))
# Out:
# Jaka jest odległość od Ziemi do Księżyca? Odległość między Ziemi a Księżyca jest równa 1,523 miliardom km. Oto 1500000000 km. To bardzo dużo, ale to jest naprawdę bardzo dużo. Jakie jest odległość od Ziemi do Księżyca w kilometrach? Ile miliona km to 1,523 miliard km? Ile miliona km to 1,523 miliard km? Ile miliona km to 1,523 miliard km? Ile miliona km to 1,523 miliard km?
#
# Najpierw, odległość od Ziemi do
